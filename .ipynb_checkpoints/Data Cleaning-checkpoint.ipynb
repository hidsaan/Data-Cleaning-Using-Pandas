# %%
import pandas as pd
data=pd.read_excel('twitter-sample.xlsx')
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 95    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 96    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 97    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 98    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# 99    119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000 2017
#
#                                                  text  response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...           119236.0
# ...

# %%
#Remove all the duplicated rows:
data.drop_duplicates()
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 88    119329       UPSHelp    False  Wed Oct 11 13:56:00 +0000 2017
# 89    119330        105859     True  Wed Oct 11 13:50:42 +0000 2017
# 90    119331        105860     True  Wed Oct 11 13:47:14 +0000 2017
# 91    119332         Tesco    False  Wed Oct 11 13:34:06 +0000 2017
# 92    119333        105861     True  Wed Oct 11 14:05:18 +0000 2017
#
#                                                  text  response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...       1.192360e+05
# ...

# %%
#Dropping the unnecessary data:
'''
df1=data.drop(columns=['response_tweet_id',	'in_response_to_tweet_id'])  #Removing multiple columns
df1'''

df2=data.drop(columns='in_response_to_tweet_id')
df2
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 95    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 96    119239        105835     True  Wed Oct 11 13:00:09 +0000 2017
# 97    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 98    119241        105836     True  Tue Oct 10 15:17:21 +0000 2017
# 99    119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000 2017
#
#                                                  text  response_tweet_id
# 0   @AppleSupport causing the reply to be disregar...           119236.0
# ...

# %%
#Snipping string from right hand side:
'''
data["created_at"]=data["created_at"].str.rstrip("2017")
data'''

#Snipping string from left hand side:
data["text"]=data["text"].str.lstrip("@")
data
# Out:
#     tweet_id     author_id  inbound                  created_at  \
# 0     119237        105834     True  Wed Oct 11 06:55:44 +0000
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000
# 2     119239        105835     True  Wed Oct 11 13:00:09 +0000
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000
# 4     119241        105836     True  Tue Oct 10 15:17:21 +0000
# ..       ...           ...      ...                         ...
# 95    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000
# 96    119239        105835     True  Wed Oct 11 13:00:09 +0000
# 97    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000
# 98    119241        105836     True  Tue Oct 10 15:17:21 +0000
# 99    119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000
#
#                                                  text  response_tweet_id  \
# 0   AppleSupport causing the reply to be disregard...           119236.0
# ...

# %%
import pandas as pd
data=pd.read_excel('twitter-sample.xlsx')

# %%
#Replacing null values with a value:
data['author_id']=data['author_id'].str.replace('NaN','1111')
data
# Out:
#     tweet_id     author_id  inbound                      created_at  \
# 0     119237           NaN     True  Wed Oct 11 06:55:44 +0000 2017
# 1     119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 2     119239           NaN     True  Wed Oct 11 13:00:09 +0000 2017
# 3     119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 4     119241           NaN     True  Tue Oct 10 15:17:21 +0000 2017
# ..       ...           ...      ...                             ...
# 95    119238  ChaseSupport    False  Wed Oct 11 13:25:49 +0000 2017
# 96    119239           NaN     True  Wed Oct 11 13:00:09 +0000 2017
# 97    119240  VirginTrains    False  Tue Oct 10 15:16:08 +0000 2017
# 98    119241           NaN     True  Tue Oct 10 15:17:21 +0000 2017
# 99    119243  VirginTrains    False  Tue Oct 10 15:25:14 +0000 2017
#
#                                                  text  response_tweet_id  \
# 0   @AppleSupport causing the reply to be disregar...           119236.0
# ...
